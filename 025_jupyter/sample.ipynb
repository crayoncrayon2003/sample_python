# %% [markdown]
# # This is Markdown Samaple
# ## This is Markdown Samaple
# ### This is Markdown Samaple
# #### This is Markdown Samaple

# %%
print("This is Code Samaple")
# Out:
# This is Code Samaple

# %% [markdown]
# # Multi-line program in one cell

# %%
a=1
b=1
c=1+1

# %% [markdown]
# # Program in Multi cell
#
# Cell is affected by the execution result of the previous cell

# %%
x=1

# %%
y=1

# %%
z=x+y

# %% [markdown]
# # Execute shell commands

# %%
# !ls
# Out:
# 1461.09s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# README.md  env	requirements.txt  sample.ipynb

# %% [markdown]
# # Line Magic & Cell Magic

# %%
# show list of Line Magic & Cell Magic
cmd = %lsmagic
print(cmd)
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cat  %cd  %clear  %code_wrap  %colors  %conda  %config  %connect_info  %cp  %debug  %dhist  %dirs  %doctest_mode  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %lf  %lk  %ll  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %lx  %macro  %magic  %mamba  %man  %matplotlib  %micromamba  %mkdir  %more  %mv  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %rep  %rerun  %reset  %reset_selective  %rm  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %uv  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# ## Line magic

# %%
# Time measurement for each command
# %time sum(range(10))
# %time sum(range(1000000))
# Out:
# CPU times: user 86 μs, sys: 22 μs, total: 108 μs
# Wall time: 143 μs
# CPU times: user 22 ms, sys: 214 μs, total: 22.2 ms
# Wall time: 21.7 ms
# 499999500000

# %% [markdown]
# # Cell magic

# %%
# Time measurement for Cell
# %%time
sum_val = 0
for i in range(1000000):
    sum_val += i
print(sum_val)
# Out:
# UsageError: Line magic function `%%time` not found.

# %% [markdown]
# # Show help

# %%
dict?
# Out:
# Init signature: dict(self, /, *args, **kwargs)
# Docstring:
# dict() -> new empty dictionary
# dict(mapping) -> new dictionary initialized from a mapping object's
#     (key, value) pairs
# dict(iterable) -> new dictionary initialized as if via:
#     d = {}
#     for k, v in iterable:
#         d[k] = v
# dict(**kwargs) -> new dictionary initialized with the name=value pairs
#     in the keyword argument list.  For example:  dict(one=1, two=2)
# Type:           type
# Subclasses:     OrderedDict, defaultdict, Counter, _EnumDict, _Quoter, Bunch, ObjectDict, ConvertingDict, Config, _DefaultOptionDict, ...

# %% [markdown]
# # Show Code

# %%
def test(a,b):
    return a+b

# %%
test??
# Out:
# Signature: test(a, b)
# Docstring: <no docstring>
# Source:
# def test(a,b):
#     return a+b
# File:      /tmp/ipykernel_7635/4066892908.py
# Type:      function
